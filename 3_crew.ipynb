# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM

llm=LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.1
)

# %%
from crewai import Agent , Task , Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

crew=Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)
crew.kickoff(inputs={"topic": " The future of AI"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  14ef2d3c-8ad6-4977-9da2-5ac855b2fac1                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about  The future of AI.                                           │
# │  ID: 31f2ae93-3b8c-4ffb-9ed3-50ec452b641c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about  The future of AI.                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 3-5 interesting and recent facts about the future of AI:                                              │
# │                                                                                                                 │
# │  *   **Accelerated AGI Timelines:** Many prominent AI researchers and industry leaders, including OpenAI's Sam  │
# │  Altman and Nvidia's Jensen Huang, have recently expressed beliefs that Artificial General Intelligence (AGI)   │
# │  could be achieved within the next 5-10 years, though the precise definition and implications of AGI remain     │
# │  subjects of intense debate.                                                                                    │
# │  *   **Rise of Multimodal and Embodied AI:** The future of AI is rapidly progressing beyond single-modality     │
# │  systems (like text-only or image-only) towards multimodal AI that can seamlessly understand and generate       │
# │  content across text, images, audio, and video (e.g., Google Gemini, OpenAI's Sora). Concurrently, embodied     │
# │  AI, where intelligent agents interact with the physical world through robotics, is gaining traction,           │
# │  promising more versatile and real-world applicable AI.                                                         │
# │  *   **AI as a Scientific Accelerator:** AI is increasingly becoming an indispensable tool for accelerating     │
# │  scientific discovery, from rapidly identifying new drug candidates and materials to improving climate models   │
# │  and fusion energy research, potentially compressing decades of traditional research into significantly         │
# │  shorter periods.                                                                                               │
# │  *   **Intensified Global Regulatory Push:** Governments and international bodies worldwide are actively        │
# │  developing and implementing comprehensive AI regulations (e.g., the EU AI Act, the US Executive Order on AI)   │
# │  to address growing concerns around safety, ethics, bias, and accountability, indicating a future where AI      │
# │  development will be significantly shaped by legal and ethical frameworks.                                      │
# │  *   **Growing Sustainability Challenge:** The immense computational power required to train and run            │
# │  increasingly large and complex AI models is leading to a significant increase in energy consumption and        │
# │  carbon footprint, making AI sustainability and the development of more energy-efficient algorithms a critical  │
# │  challenge for its future growth and widespread adoption.                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Find 3-5 interesting and recent facts about  The future of AI.                                                 │
# │  Agent:                                                                                                         │
# │  Research Specialist                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about  The future of AI using the facts from the research.            │
# │  ID: ae2708f2-956d-4c65-af51-cfc0e9596665                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about  The future of AI using the facts from the research.            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of AI is rapidly unfolding. Many experts now believe Artificial General Intelligence (AGI) could    │
# │  emerge within 5-10 years. We're witnessing a surge in multimodal AI, like Google Gemini and OpenAI's Sora,     │
# │  seamlessly understanding text, images, and video, alongside embodied AI interacting physically. AI is also a   │
# │  powerful scientific accelerator, speeding up drug discovery and climate modeling. However, this progress       │
# │  brings challenges: a global push for comprehensive AI regulations (e.g., EU AI Act) to ensure safety and       │
# │  ethics, and a significant sustainability concern due to the massive energy consumption of large AI models.     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Write a 100-word blog post summary about  The future of AI using the facts from the research.                  │
# │  Agent:                                                                                                         │
# │  Creative Writer                                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# CrewOutput(raw="The future of AI is rapidly unfolding. Many experts now believe Artificial General Intelligence (AGI) could emerge within 5-10 years. We're witnessing a surge in multimodal AI, like Google Gemini and OpenAI's Sora, seamlessly understanding text, images, and video, alongside embodied AI interacting physically. AI is also a powerful scientific accelerator, speeding up drug discovery and climate modeling. However, this progress brings challenges: a global push for comprehensive AI regulations (e.g., EU AI Act) to ensure safety and ethics, and a significant sustainability concern due to the massive energy consumption of large AI models.", pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about  The future of AI.', name='Find 3-5 interesting and recent facts about  The future of AI.', expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about  The future...', raw="Here are 3-5 interesting and recent facts about the future of AI:\n\n*   **Accelerated AGI Timelines:** Many prominent AI researchers and industry leaders, including OpenAI's Sam Altman and Nvidia's Jensen Huang, have recently expressed beliefs that Artificial General Intelligence (AGI) could be achieved within the next 5-10 years, though the precise definition and implications of AGI remain subjects of intense debate.\n*   **Rise of Multimodal and Embodied AI:** The future of AI is rapidly progressing beyond single-modality systems (like text-only or image-only) towards multimodal AI that can seamlessly understand and generate content across text, images, audio, and video (e.g., Google Gemini, OpenAI's Sora). Concurrently, embodied AI, where intelligent agents interact with the physical world through robotics, is gaining traction, promising more versatile and real-world applicable AI.\n*   **AI as a Scientific Accelerator:** AI is increasingly becoming an indispensable tool for accelerating scientific discovery, from rapidly identifying new drug candidates and materials to improving climate models and fusion energy research, potentially compressing decades of traditional research into significantly shorter periods.\n*   **Intensified Global Regulatory Push:** Governments and international bodies worldwide are actively developing and implementing comprehensive AI regulations (e.g., the EU AI Act, the US Executive Order on AI) to address growing concerns around safety, ethics, bias, and accountability, indicating a future where AI development will be significantly shaped by legal and ethical frameworks.\n*   **Growing Sustainability Challenge:** The immense computational power required to train and run increasingly large and complex AI models is leading to a significant increase in energy consumption and carbon footprint, making AI sustainability and the development of more energy-efficient algorithms a critical challenge for its future growth and widespread adoption.", pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data.\nYour personal goal is: Research interesting facts about the topic:  The future of AI'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting and recent facts about  The future of AI.\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nProvide your complete response:'}, {'role': 'assistant', 'content': "Here are 3-5 interesting and recent facts about the future of AI:\n\n*   **Accelerated AGI Timelines:** Many prominent AI researchers and industry leaders, including OpenAI's Sam Altman and Nvidia's Jensen Huang, have recently expressed beliefs that Artificial General Intelligence (AGI) could be achieved within the next 5-10 years, though the precis ...
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
#
# ┌───────────────────────── Tracing Preference Saved ──────────────────────────┐
# │                                                                             │
# │  Info: Tracing has been disabled.                                           │
# │                                                                             │
# │  Your preference has been saved. Future Crew/Flow executions will not       │
# │  collect traces.                                                            │
# │                                                                             │
# │  To enable tracing later, do any one of these:                              │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  14ef2d3c-8ad6-4977-9da2-5ac855b2fac1                                                                           │
# │  Final Output: The future of AI is rapidly unfolding. Many experts now believe Artificial General Intelligence  │
# │  (AGI) could emerge within 5-10 years. We're witnessing a surge in multimodal AI, like Google Gemini and        │
# │  OpenAI's Sora, seamlessly understanding text, images, and video, alongside embodied AI interacting             │
# │  physically. AI is also a powerful scientific accelerator, speeding up drug discovery and climate modeling.     │
# │  However, this progress brings challenges: a global push for comprehensive AI regulations (e.g., EU AI Act) to  │
# │  ensure safety and ethics, and a significant sustainability concern due to the massive energy consumption of    │
# │  large AI models.                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
